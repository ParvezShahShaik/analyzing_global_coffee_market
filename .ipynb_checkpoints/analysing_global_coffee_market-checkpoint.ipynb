# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Coffee Production Stats
# * create a bar chart of the top 10 coffee producers by total production in 'totoal-production.csv' sorted from highest to lowest. Change the xticks to two letter country abbreviations

# %%
coffee_production= pd.read_csv("/Users/parvezshahshaik/Documents/Github/analyzing_global_coffee_market/Data/coffee/total-production.csv").T #This "T" is called transpose. this rotates our data frame

coffee_production.columns = coffee_production.iloc[0] #This will transfer the countries to heading

coffee_production = coffee_production.drop("total_production") #This will drop or del the additional heading

# %%
coffee_production.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# ...

# %%
coffee_production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 1990 to 2018
# Data columns (total 56 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Angola                            29 non-null     object
#  1   Bolivia (Plurinational State of)  29 non-null     object
#  2   Brazil                            29 non-null     object
#  3   Burundi                           29 non-null     object
#  4   Ecuador                           29 non-null     object
#  5   Indonesia                         29 non-null     object
#  6   Madagascar                        29 non-null     object
#  7   Malawi                            29 non-null     object
#  8   Papua New Guinea                  29 non-null     object
#  9   Paraguay                          29 non-null     object
#  10  Peru                              29 non-null     object
# ...

# %%
top10_producers = coffee_production.sum()
top10_producers.head()
# Out:
# total_production
# Angola                                 1312.4254
# Bolivia (Plurinational State of)       3368.2377
# Brazil                              1190965.7353
# Burundi                               10155.0003
# Ecuador                               31218.6262
# dtype: object

# %%
#sorting the above list in descending order
top10_producers = coffee_production.sum().sort_values(ascending=False).iloc[:10]
top10_producers.head()
# Out:
# total_production
# Brazil       1190965.7353
# Viet Nam      439540.9519
# Colombia      345871.4464
# Indonesia     245116.7707
# Ethiopia      141542.8931
# dtype: object

# %% [markdown]
# ## Creating a Bar Chart:

# %%
fig, ax = plt.subplots(figsize=(8, 8))

ax.bar(x=top10_producers.index, height=top10_producers/1000000)

positions = list(range(10))
labels = ["BR", "VN", "CO", "ID","ET", "IN", "MX", "GT", "HN", "UG"]

ax.set_title("Top Coffee Producing Nations 1990-2018")
ax.set_ylabel("Production (Millions 60kg Bags)", fontsize=14)

ax.set_xticks(positions)
ax.set_xticklabels(labels)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.show()
